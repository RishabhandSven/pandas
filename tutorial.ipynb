# %%
# %pip install pandas
import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 5.2 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.0 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 4.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.2/11.0 MB 5.0 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.0 MB 5.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 4.9 MB/s eta 0:00:01
# ...

# %%
print("HEllo World")
# Out:
# HEllo World

# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=["A","B","C"], index=["row1","row2","row3"])
df.head()
# Out:
#       A  B  C
# row1  1  2  3
# row2  4  5  6
# row3  7  8  9

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df['A'].unique()
# Out:
# array([1, 4, 7])

# %%
df.shape
# Out:
# (3, 3)
